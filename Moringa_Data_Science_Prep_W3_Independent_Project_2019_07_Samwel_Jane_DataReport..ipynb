# %%
# import required libraries
import  pandas as pd
import numpy as np

# %%
#load description file wich is an xlsx
df_description = pd.read_excel('CDR_description.xlsx')
df_description
# Out:
#        Column name                                        Description   Format
# 0          PRODUCT                                       Voice or SMS   String
# 1            VALUE                                      Billing price  Integer
# 2        DATE_TIME               Time in format yyyy-MM-dd hh:mm:ss.0   String
# 3     CELL_ON_SITE  Which cell in the site was used (not needed here)  Integer
# 4  DW_A_NUMBER_INT  Anonymized phone number of the person for whic...   String
# 5  DW_B_NUMBER_INT        Anonymized phone number of the counterparty   String
# 6        COUNTRY_A                  Country of party A (useless here)   String
# 7        COUNTRY_B                  Country of party B (useless here)   String
# 8          CELL_ID                                     ID of the cell   String
# 9          SITE_ID                                     ID of the SITE   String

# %%
df = pd.read_csv('cells_geo.csv',delimiter=';')
df.head()
# Out:
#    Unnamed: 0   VILLES      STATUS LOCALISATION    DECOUPZONE  ZONENAME  \
# 0           0   ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW
# 1           1   ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW
# 2           2   ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW
# 3           3  ASSINIE  In Service    INTERIEUR     Grand-EST  ASSINIE"
# 4           4  ASSINIE  In Service    INTERIEUR     Grand-EST  ASSINIE"
#
#    LONGITUDE  LATITUDE     REGION AREA     CELL_ID   SITE_CODE
# 0  -4.000667  5.368194     LAGUNE  NaN  fbb2e75af3  0bb492ef17
# 1  -4.000667  5.368194     LAGUNE  NaN  1502501d78  0bb492ef17
# 2  -4.000667  5.368194     LAGUNE  NaN  0c2e182a0c  0bb492ef17
# 3  -3.488467  5.158761  SUD COMOE  NaN  69bdfc69fd  8a1e6ce31f
# 4  -3.488467  5.158761  SUD COMOE  NaN  7a1029d2ab  8a1e6ce31f

# %%
#rename the columns
df_new = df.rename(columns ={'VILLES':'CITIES','ZONENAME':'ZONE_NAME','SITE_CODE':'SITE_ID'})
df_new.columns
# Out:
# Index(['Unnamed: 0', 'CITIES', 'STATUS', 'LOCALISATION', 'DECOUPZONE',
#        'ZONE_NAME', 'LONGITUDE', 'LATITUDE', 'REGION', 'AREA', 'CELL_ID',
#        'SITE_ID'],
#       dtype='object')

# %%
#dropping columns that don't contain relevant information based on our question.
df_new.drop(columns=['AREA','LONGITUDE','LATITUDE','Unnamed: 0']).head()
# Out:
#     CITIES      STATUS LOCALISATION    DECOUPZONE ZONE_NAME     REGION  \
# 0   ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW     LAGUNE
# 1   ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW     LAGUNE
# 2   ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW     LAGUNE
# 3  ASSINIE  In Service    INTERIEUR     Grand-EST  ASSINIE"  SUD COMOE
# 4  ASSINIE  In Service    INTERIEUR     Grand-EST  ASSINIE"  SUD COMOE
#
#       CELL_ID     SITE_ID
# 0  fbb2e75af3  0bb492ef17
# 1  1502501d78  0bb492ef17
# 2  0c2e182a0c  0bb492ef17
# 3  69bdfc69fd  8a1e6ce31f
# 4  7a1029d2ab  8a1e6ce31f

# %%
#unique values and counts of all columns
df_new.apply(pd.Series.value_counts).head()
# Out:
#            Unnamed: 0  CITIES  STATUS  LOCALISATION  DECOUPZONE  ZONE_NAME  \
# -8.503889         NaN     NaN     NaN           NaN         NaN        NaN
# -8.408611         NaN     NaN     NaN           NaN         NaN        NaN
# -8.406667         NaN     NaN     NaN           NaN         NaN        NaN
# -8.315833         NaN     NaN     NaN           NaN         NaN        NaN
# -8.302222         NaN     NaN     NaN           NaN         NaN        NaN
#
#            LONGITUDE  LATITUDE  REGION  AREA  CELL_ID  SITE_ID
# -8.503889        3.0       NaN     NaN   NaN      NaN      NaN
# -8.408611        3.0       NaN     NaN   NaN      NaN      NaN
# -8.406667        3.0       NaN     NaN   NaN      NaN      NaN
# -8.315833        3.0       NaN     NaN   NaN      NaN      NaN
# -8.302222        3.0       NaN     NaN   NaN      NaN      NaN

# %%
df_7 = pd.read_csv('MoringaSchool_CB_CDR_20120507.csv')
df_7.head()
# Out:
#   PRODUTC  VALUE               DATETIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0   Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1     sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2     sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3   Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4   Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
#
#    DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0  1a49f8b0ded9de6     19e2e     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1  93343ba6e41af95     19e2e     19e2e  /+cKZKIp41  /+cKZKIp41
# 2  7aacc9709ce0a20     19e2e     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3  6af4a60e74c91d3     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4  02aa736ee555d5c     19e2e     19e2e  051KhYDCpv  051KhYDCpv

# %%
df_8 = pd.read_csv('MoringaSchool_CB_CDR_20120508.csv')
df_8.head()
# Out:
#   PRODUCT  VALUE              DATE_TIME CELL_ON_SITE      DW_A_NUMBER  \
# 0     sms      0  2012-05-07 23:02:06.0            2  32255675c3b6fe3
# 1   Voice      0  2012-05-07 23:03:44.0            1  ff16d6ac74c1c64
# 2     sms      0  2012-05-07 23:04:06.0            0  98d9f2fb5ff624b
# 3   Voice     37  2012-05-07 23:04:48.0            1  3f9c8a33ec7be1f
# 4     sms     25  2012-05-07 23:04:58.0            1  7bcccc03adf3864
#
#        DW_B_NUMBER COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0  1aa7ae01386e9fb     19e2e     19e2e  +854AcBQT2  +854AcBQT2
# 1  87d87309c15a8c9     19e2e     19e2e  +854AcBQT2  +854AcBQT2
# 2  93343ba6e41af95     19e2e     19e2e  +laSrk7g6q  +laSrk7g6q
# 3  7d05a38f89c49d8     19e2e     19e2e  /xvRrCVKoQ  /xvRrCVKoQ
# 4  56a5d5430d2fa86     19e2e     19e2e  +bO+qkSonO  +bO+qkSonO

# %%
df.rename
# Out:
# <bound method DataFrame.rename of       Unnamed: 0       VILLES      STATUS LOCALISATION       DECOUPZONE  \
# 0              0       ADJAME  In Service      ABIDJAN     "Abidjan_EST
# 1              1       ADJAME  In Service      ABIDJAN     "Abidjan_EST
# 2              2       ADJAME  In Service      ABIDJAN     "Abidjan_EST
# 3              3      ASSINIE  In Service    INTERIEUR        Grand-EST
# 4              4      ASSINIE  In Service    INTERIEUR        Grand-EST
# 5              5      ASSINIE  In Service    INTERIEUR        Grand-EST
# 6              6     KRIKOREA  In Service    INTERIEUR      Grand-OUEST
# 7              7        ABOBO  In Service      ABIDJAN    "Abidjan_NORD
# 8              8        ABOBO  In Service      ABIDJAN    "Abidjan_NORD
# 9              9        ABOBO         NaN      ABIDJAN    "Abidjan_NORD
# 10            10        ABOBO         NaN      ABIDJAN    "Abidjan_NORD
# 11            11        ABOBO  In Service      ABIDJAN    "Abidjan_NORD
# ...

# %%
df_9 = pd.read_csv('MoringaSchool_CB_CDR_20120509.csv')
df_9.tail()
# Out:
#          PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 14834796   Voice     14  2012-05-10 00:55:42.0            2  b06224c153dee8d
# 14834797     sms      0  2012-05-10 00:55:51.0            2  e350a3354469710
# 14834798     sms      0  2012-05-10 00:55:53.0            1  20d4e82af4c2e37
# 14834799     sms     25  2012-05-10 00:57:11.0            1  22a9b87e67cd331
# 14834800     sms      0  2012-05-10 00:59:04.0            2  9425175f71f05d9
#
#           DW_B_NUMBER_INT COUNTRY_A COUNTRY_B      CELLID     SIET_ID
# 14834796  4d1a8af24ea36d5     19e2e     19e2e  zsA2dnzCR5  zsA2dnzCR5
# 14834797  0fdbd19a0598f60     19e2e     19e2e  xxbbz32oIL  xxbbz32oIL
# 14834798  f29aa856dc3a8ef     19e2e     19e2e  zbVRn1hiwe  zbVRn1hiwe
# 14834799  d91e5f4fcf14297     19e2e     19e2e  yPq8TPd7WC  yPq8TPd7WC
# 14834800  bfdd4b8e596ef48     19e2e     19e2e  zqHx55Evcc  zqHx55Evcc

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3974 entries, 0 to 3973
# Data columns (total 12 columns):
# Unnamed: 0      3974 non-null int64
# VILLES          3974 non-null object
# STATUS          3907 non-null object
# LOCALISATION    3974 non-null object
# DECOUPZONE      3974 non-null object
# ZONENAME        3968 non-null object
# LONGITUDE       3974 non-null float64
# LATITUDE        3974 non-null float64
# REGION          3974 non-null object
# AREA            3951 non-null object
# CELL_ID         3974 non-null object
# SITE_CODE       3974 non-null object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 372.6+ KB

# %%
df_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15011816 entries, 0 to 15011815
# Data columns (total 10 columns):
# PRODUTC            object
# VALUE              int64
# DATETIME           object
# CELL_ON_SITE       object
# DW_A_NUMBER_INT    object
# DW_B_NUMBER_INT    object
# COUNTRY_A          object
# COUNTRY_B          object
# CELL_ID            object
# SITE_ID            object
# dtypes: int64(1), object(9)
# memory usage: 1.1+ GB

# %%
df_8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19606112 entries, 0 to 19606111
# Data columns (total 10 columns):
# PRODUCT         object
# VALUE           int64
# DATE_TIME       object
# CELL_ON_SITE    object
# DW_A_NUMBER     object
# DW_B_NUMBER     object
# COUNTRY_A       object
# COUNTRY_B       object
# CELL_ID         object
# SITE_ID         object
# dtypes: int64(1), object(9)
# memory usage: 1.5+ GB

# %%
df_9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14834801 entries, 0 to 14834800
# Data columns (total 10 columns):
# PRODUCT            object
# VALUE              int64
# DATE_TIME          object
# CELL_ON_SITE       object
# DW_A_NUMBER_INT    object
# DW_B_NUMBER_INT    object
# COUNTRY_A          object
# COUNTRY_B          object
# CELLID             object
# SIET_ID            object
# dtypes: int64(1), object(9)
# memory usage: 1.1+ GB

# %%
df_7_new = df_7.rename(columns = {'PRODUTC':'PRODUCT','DATETIME':'DATE_TIME'})
df_7_new.columns
# Out:
# Index(['PRODUCT', 'VALUE', 'DATE_TIME', 'CELL_ON_SITE', 'DW_A_NUMBER_INT',
#        'DW_B_NUMBER_INT', 'COUNTRY_A', 'COUNTRY_B', 'CELL_ID', 'SITE_ID'],
#       dtype='object')

# %%
df_8_new = df_8.rename(columns={'DW_A_NUMBER':'DW_A_NUMBER_INT','DW_B_NUMBER':'DW_B_NUMBER_INT'})
df_8_new.columns
# Out:
# Index(['PRODUCT', 'VALUE', 'DATE_TIME', 'CELL_ON_SITE', 'DW_A_NUMBER_INT',
#        'DW_B_NUMBER_INT', 'COUNTRY_A', 'COUNTRY_B', 'CELL_ID', 'SITE_ID'],
#       dtype='object')

# %%
#df_9_new = df_9.rename(columns ={'CELLID':'CELL_ID','SIET_ID':'SITE_ID'})
#df_9_new
#Rename columns
df_9_new = df_9.rename(columns ={'CELLID':'CELL_ID','SIET_ID':'SITE_ID'})
df_9_new.columns
# Out:
# Index(['PRODUCT', 'VALUE', 'DATE_TIME', 'CELL_ON_SITE', 'DW_A_NUMBER_INT',
#        'DW_B_NUMBER_INT', 'COUNTRY_A', 'COUNTRY_B', 'CELL_ID', 'SITE_ID'],
#       dtype='object')

# %%
#joining table df_7_new,df_8_new,df_9_new to form on table called df_COMBINE
df_COMBINE=pd.concat([df_7_new,df_8_new,df_9_new],ignore_index=True)
df_COMBINE.tail()
# Out:
#          PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 49452724   Voice     14  2012-05-10 00:55:42.0            2  b06224c153dee8d
# 49452725     sms      0  2012-05-10 00:55:51.0            2  e350a3354469710
# 49452726     sms      0  2012-05-10 00:55:53.0            1  20d4e82af4c2e37
# 49452727     sms     25  2012-05-10 00:57:11.0            1  22a9b87e67cd331
# 49452728     sms      0  2012-05-10 00:59:04.0            2  9425175f71f05d9
#
#           DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 49452724  4d1a8af24ea36d5     19e2e     19e2e  zsA2dnzCR5  zsA2dnzCR5
# 49452725  0fdbd19a0598f60     19e2e     19e2e  xxbbz32oIL  xxbbz32oIL
# 49452726  f29aa856dc3a8ef     19e2e     19e2e  zbVRn1hiwe  zbVRn1hiwe
# 49452727  d91e5f4fcf14297     19e2e     19e2e  yPq8TPd7WC  yPq8TPd7WC
# 49452728  bfdd4b8e596ef48     19e2e     19e2e  zqHx55Evcc  zqHx55Evcc

# %%
#dropping columns;COUNTRY_A AND COUNTRY_B IN ORDER TO COME WITH A NEW TABLE CALLED df_COMBINE_NEW
df_COMBINE_NEW = df_7_new.drop(columns = ['COUNTRY_A','COUNTRY_B','CELL_ON_SITE'])
df_COMBINE_NEW.head()
# Out:
#   PRODUCT  VALUE              DATE_TIME  DW_A_NUMBER_INT  DW_B_NUMBER_INT  \
# 0   Voice      0  2012-05-06 23:04:37.0  49fae048b547780  1a49f8b0ded9de6
# 1     sms      0  2012-05-06 23:05:25.0  7a54a6eaee19e65  93343ba6e41af95
# 2     sms     25  2012-05-06 23:05:41.0  6008887b0207d82  7aacc9709ce0a20
# 3   Voice     56  2012-05-06 23:05:42.0  7370032e20f4e96  6af4a60e74c91d3
# 4   Voice     14  2012-05-06 23:06:29.0  966ba4656e38e62  02aa736ee555d5c
#
#       CELL_ID     SITE_ID
# 0  /TJNe+Mmtu  /TJNe+Mmtu
# 1  /+cKZKIp41  /+cKZKIp41
# 2  /u0FSD+ahi  /u0FSD+ahi
# 3  +cNeJzsTp3  +cNeJzsTp3
# 4  051KhYDCpv  051KhYDCpv

# %%
# describe a statatistical summary  of our new combined table

df_COMBINE_NEW.describe()
# Out:
#               VALUE
# count  1.501182e+07
# mean   4.255369e+01
# std    9.046932e+01
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    1.400000e+01
# 75%    5.400000e+01
# max    2.496000e+04

# %%
#check the number of row and columns in our dataset
df_COMBINE_NEW.shape
# Out:
# (15011816, 7)

# %%
#check unique values of VALUE
df_COMBINE_NEW['VALUE'].unique()
# Out:
# array([   0,   25,   56, ..., 2034, 4390, 2748])

# %%
#check frequency of unique values
df_COMBINE_NEW['VALUE'].value_counts()
# Out:
# 0       6179336
# 30       372555
# 60       309917
# 25       236537
# 90       184892
# 50       154293
# 14       139761
# 12       133786
# 24       131466
# 2        130507
# 18       126623
# 26       125165
# 20       123214
# 120      112966
# 1        112162
# 17       111342
# 15       110949
# 21       110522
# 10       106972
# 32       103138
# 38        99413
# 40        96846
# 28        96521
# 36        95533
# 11        95124
# 16        93728
# 42        93582
# 22        90488
# 8         90109
# 100       88035
#          ...
# 2611          1
# 2610          1
# 2615          1
# 2620          1
# 2527          1
# 2518          1
# 2435          1
# 2517          1
# 2437          1
# 2440          1
# 2447          1
# 2446          1
# 2451          1
# 2452          1
# 2456          1
# 2458          1
# 2460          1
# 2465          1
# 2468          1
# 2471          1
# 2477          1
# 2486          1
# 2492          1
# 2499          1
# ...

# %%
# check the row indexes (row numbers)
df_COMBINE_NEW.index
# Out:
# RangeIndex(start=0, stop=15011816, step=1)

# %%
df_COMBINE_NEW.PRODUCT.describe()
# Out:
# count     15011816
# unique           3
# top          Voice
# freq       9898239
# Name: PRODUCT, dtype: object

# %%
#sorting our data basd on PRODUCT
df_COMBINE_NEW.sort_values(['PRODUCT'],ascending=False).head()
# Out:
#         PRODUCT  VALUE              DATE_TIME  DW_A_NUMBER_INT  \
# 7505908     sms      0  2012-05-07 14:53:51.0  8adf0fbd821ec2d
# 8071858     sms      0  2012-05-07 15:41:46.0  a679ba5566b22a2
# 8071873     sms      0  2012-05-07 15:41:46.0  7cc2d9f85adc85d
# 8071872     sms      0  2012-05-07 15:41:46.0  720346dcc5aab85
# 8071871     sms      0  2012-05-07 15:41:46.0  82cc93c9363f806
#
#          DW_B_NUMBER_INT     CELL_ID     SITE_ID        DATE        TIME
# 7505908  a30688fa582892c  b35d189fd8  b5bd954080  2012-05-07  14:53:51.0
# 8071858  aaaf0e4bdec7311  3f441d89ab  bcb0672194  2012-05-07  15:41:46.0
# 8071873  93343ba6e41af95  62c1154f7d  4f81d93bc5  2012-05-07  15:41:46.0
# 8071872  93343ba6e41af95  616668c72a  a31cda32b8  2012-05-07  15:41:46.0
# 8071871  6485d7b860dcee7  eab7fefe09  ea78593acf  2012-05-07  15:41:46.0

# %%
#check tha mean of VALUE
df_COMBINE_NEW.VALUE.mean()
# Out:
# 42.55369270446693

# %%
df_COMBINE_NEW.isnull().sum()
# Out:
# PRODUCT                 0
# VALUE                   0
# DATE_TIME               0
# DW_A_NUMBER_INT         0
# DW_B_NUMBER_INT         0
# CELL_ID                 0
# SITE_ID            540033
# dtype: int64

# %%
df_COMBINE_NEW_F = df_COMBINE_NEW.merge(df_new, how='left', on='CELL_ID')

# %%
df_COMBINE_NEW_F.isnull().sum()
# Out:
# PRODUCT                   0
# VALUE                     0
# DATE_TIME                 0
# DW_A_NUMBER_INT           0
# DW_B_NUMBER_INT           0
# CELL_ID                   0
# SITE_ID_x            540035
# DATE                      0
# TIME                      0
# Unnamed: 0         15011642
# CITIES             15011642
# STATUS             15011643
# LOCALISATION       15011642
# DECOUPZONE         15011642
# ZONE_NAME          15011642
# LONGITUDE          15011642
# LATITUDE           15011642
# REGION             15011642
# AREA               15011642
# SITE_ID_y          15011642
# dtype: int64

# %%
#seperate the column date into two dates one for the date and another one for time
#df_COMBINE_NEW[['DATE'],['TIME']]=DATE_DATE.str.split(expand=True)
df_COMBINE_NEW_F[['DATE', 'TIME']] = df_COMBINE_NEW.DATE_TIME.str.split(expand=True)
